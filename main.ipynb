# %% [markdown]
# ## Big Data Processing with Logstash

# %% [markdown]
# **Business Problem:** Microsoft want to control data as Firewall Log on Elasticsearch UI by using Logstash pipeline.

# %% [markdown]
# ## Run Docker Services

# %%
# !docker-compose up -d

# %%
# !docker-compose ps

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !docker cp datasets/firewall-log.json logstash:/tmp

# %% [markdown]
# Copy *firewall-log.json* data to logstash.

# %%
# !docker exec -it logstash bash

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# ls -l /tmp/

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ## Pipeline Preparation

# %%
# vi pipeline/json_log.conf

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Create to pipeline for sending Firewall log file to Elasticsearch.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As seen on Elasticsearch UI which named as Kibana .firewall_log was created.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Writed SQL query for seeing data.

# %% [markdown]
# ## Filtering

# %% [markdown]
# Filter dynamically as automated with logstash pipeline. Configure *json_log.conf* file as above sql query.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Data is like above when see the logstash's logs.

# %%
# vi pipeline/json_log.conf.conf

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %% [markdown]
# Configured *json_log.conf* file as above. Filtering was automated. Let's see on Kibana.

# %% [markdown]
# Run the sql query;<br><br>
# ![image.png](attachment:image.png)<br><br>
# filtering is successed.

# %% [markdown]
# ## Save Log to File with Date

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# ls /tmp/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Configurated to *json_log.conf* for saving log files with date in tmp file.
